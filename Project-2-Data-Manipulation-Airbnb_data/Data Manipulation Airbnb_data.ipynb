# %%
import pandas as pd

# %%
df=pd.read_csv('Airbnb_Open_Data (1).csv')
# Out:
# C:\Users\AKASH\AppData\Local\Temp\ipykernel_32300\1396479858.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('Airbnb_Open_Data (1).csv')

# %%
df.head(10)
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5  1004098         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 6  1004650                                   BlissArtsSpace!  61300605564
# 7  1005202                                   BlissArtsSpace!  90821839709
# 8  1005754                   Large Furnished Room Near B'way  79384379533
# 9  1006307                Cozy Clean Guest Room - Family Apt  75527839483
#
#   host_identity_verified host name neighbourhood group       neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn          Kensington
# ...

# %%
#2. Show the last 5 rows of the dataset.

df.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee minimum nights  \
# ...

# %%
#3. Get all column names in the dataset.

df.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
#4. Display the shape (rows, columns) of the dataset.

df.shape
# Out:
# (102599, 26)

# %%
#5. Check the data type of each column.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
# ...

# %%
#6. Display only the columns: name, price, and room_type.

df[['NAME','price','room type']]
# Out:
#                                                     NAME    price  \
# 0                     Clean & quiet apt home by the park    $966
# 1                                  Skylit Midtown Castle    $142
# 2                    THE VILLAGE OF HARLEM....NEW YORK !    $620
# 3                                                    NaN    $368
# 4       Entire Apt: Spacious Studio/Loft by central park    $204
# ...                                                  ...      ...
# 102594                        Spare room in Williamsburg    $844
# 102595                     Best Location near Columbia U    $837
# 102596                    Comfy, bright room in Brooklyn    $988
# 102597                  Big Studio-One Stop from Midtown    $546
# 102598                              585 sf Luxury Studio  $1,032
#
#               room type
# 0          Private room
# 1       Entire home/apt
# 2          Private room
# 3       Entire home/apt
# 4       Entire home/apt
# ...                 ...
# ...

# %%
#7 Retrieve all unique values in the room_type column.

df['room type'].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room', 'Hotel room'],
#       dtype=object)

# %%
# 8. Count how many unique host IDs exist in the dataset.

df['host id'].unique()
# Out:
# array([80014485718, 52335172823, 78829239556, ..., 23801060917,
#        15593031571, 93578954226], dtype=int64)

# %%
df['price'].isna().sum()
# Out:
# 247

# %%
import re
df['price']=df['price'].replace(r'[$,]','',regex=True)

# %%
df['price']=pd.to_numeric(df['price'])

# %%
#9 9. Select all rows where price is greater than 100.

df[df['price']>100]
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
#10. Select all listings where room_type is “Entire home/apt”.

df[df['room type']=='Entire home/apt']
# Out:
#              id                                              NAME  \
# 1       1002102                             Skylit Midtown Castle
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# 5       1004098         Large Cozy 1 BR Apartment In Midtown East
# 10      1006859                Cute & Cozy Lower East Side 1 bdrm
# ...         ...                                               ...
# 102590  6090228               Wonderful artists' loft in Brooklyn
# 102591  6090781                Columbus Ave Apt 1 block from Park
# 102592  6091333               3BR/1 Ba in TriBeCa w/ outdoor deck
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 1       52335172823               verified        Jenna           Manhattan
# ...

# %%
#11. Show all listings in the city “New York”.

a = df[df['neighbourhood'].str.contains('york', case=False, na=False)]
a
# Out:
#               id                                          NAME      host id  \
# 522      1289637             Family & Friends in New York City   9750353852
# 854      1473000           Feel like you never leave your home  54872866190
# 1042     1576833           1 Bedroom Apt - Close to JFK & City  14445647831
# 1517     1839175               Cozy Private Bedroom $800 Month  62089478705
# 2930     2619575           ON A BUDGET COZY IN BROOKLYN In NYC  47384441503
# ...          ...                                           ...          ...
# 102051  57364103           A cozy getaway, home away from home  55697801194
# 102286  20307535  Comfy, Beautiful Apt with Breakfast Included  83382332065
# 102323  20327970                      The luxury East New York  30396802642
# 102441  20393141                         Large bedroom ensuite  48039848434
# 102554   6070345                        Beautiful Private Room  47602000155
#
# ...

# %%
#12. Retrieve only the host_name and neighbourhood columns.

df[['host name','neighbourhood']]
# Out:
#           host name        neighbourhood
# 0          Madaline           Kensington
# 1             Jenna              Midtown
# 2             Elise               Harlem
# 3             Garry         Clinton Hill
# 4            Lyndon          East Harlem
# ...             ...                  ...
# 102594         Krik         Williamsburg
# 102595        Mifan  Morningside Heights
# 102596        Megan           Park Slope
# 102597  Christopher     Long Island City
# 102598      Rebecca      Upper West Side
#
# [102599 rows x 2 columns]

# %%
#13 13. Display all listings with more than 2 bedrooms.
df['room type'].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room', 'Hotel room'],
#       dtype=object)

# %%
# 14. Retrieve all listings that have a minimum_nights less than 3.

df[df['minimum nights']<3]
# Out:
#              id                                              NAME  \
# 8       1005754                   Large Furnished Room Near B'way
# 9       1006307                Cozy Clean Guest Room - Family Apt
# 10      1006859                Cute & Cozy Lower East Side 1 bdrm
# 12      1007964                   Central Manhattan/near Broadway
# 14      1009068  Wonderful Guest Bedroom in Manhattan for SINGLES
# ...         ...                                               ...
# 102593  6091885               Welcoming, Clean, Cheap on St Marks
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 8       79384379533               verified       Evelyn           Manhattan
# ...

# %%
#15 Show listings where availability_365 is zero.

df[df['availability 365']==0]
# Out:
#               id                                             NAME  \
# 154      1086390                                              NaN
# 243      1135545                                Huge Chelsea Loft
# 862      1477419              Your Own 2 Br Apt Bedford and Grand
# 1541     1852430              LARGE PRIVATE FLOOR IN BROOKLYN, NY
# 2408     2331274              Central Park Room/Bath with a View!
# ...          ...                                              ...
# 102462  20404740                               New York Apartment
# 102463  20405292        Affordable bedroom in Brooklyn townhouse.
# 102465  20406397                  beautiful modern 1 bed room apt
# 102468  20408053  Clean, Cozy Home in Perfect Park Slope Location
# 102503   6042178              Perfect for Cat, Book, Park Lovers!
#
#             host id host_identity_verified   host name neighbourhood group  \
# 154     47292670441            unconfirmed     Dainton            Brooklyn
# ...

# %%
df.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
df['service fee']=df['service fee'].replace(r'[$,]','',regex=True)

# %%
df['service fee']=pd.to_numeric(df['service fee'])

# %%
df.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee minimum nights  \
# ...

# %%
#16. Display the top 10 most expensive listings.

df['a']=df['price']+df['service fee']

# %%
df.sort_values(by='a',ascending=False).head()
# Out:
#              id                                               NAME  \
# 53366  30475378  Modern & Beauty 3 BR in Manhattan close to Wal...
# 54631  31174037     Luxury Duplex Unit w/Private Rooftop & Balcony
# 9805    6416638                Private room in hip & historic area
# 66682  37829805    Feel-Good Decor, Lux Private Room Great Loc 4-4
# 86099  48553814             Luxurious SOHO 2 BR Washington Sq Park
#
#            host id host_identity_verified          host name  \
# 53366  10777689853            unconfirmed            Antonin
# 54631   3229595936               verified              Esaie
# 9805   40836583876            unconfirmed              Ilean
# 66682  90299456137               verified              Lydia
# 86099  43120829353               verified  Corporate Housing
#
#       neighbourhood group       neighbourhood       lat      long  \
# 53366           Manhattan  Financial District  40.70395 -74.00813
# ...

# %%
#17. Sort the dataset by price in descending order.

df.sort_values(by='price',ascending=False)
# Out:
#               id                                               NAME  \
# 64304   36516435                Great 1BD waterfront City Island NY
# 70765   40084846                  Beautiful Central Harlem sleeps 4
# 23345   13894780                                         法拉盛中心公寓楼高层
# 38851   22458743   Private room (Paris Room) in Bushwick Brownstone
# 102191  35580287   One cozy bedroom near Verrazano bridge and ferry
# ...          ...                                                ...
# 102046  57361342             Sunny budget friendly room in Bushwick
# 102047  57361894            Cozy Apartment on Bedford Ave, Brooklyn
# 102048  57362446                Your 1 bedroom home away from home!
# 102049  57362999  MASTER Cozy Bedroom Queen size 2 blocks Timesq...
# 102050  57363551        Sunny Brownstone Studio in BedStuy Brooklyn
#
#             host id host_identity_verified host name neighbourhood group  \
# 64304   83460973881               verified      Alex               Bronx
# ...

# %%
#18. Sort listings first by city, then by price ascending.

df.sort_values(by='price')[['neighbourhood','price']]
# Out:
#              neighbourhood  price
# 24254   Bedford-Stuyvesant   50.0
# 61234             Canarsie   50.0
# 69032           St. Albans   50.0
# 45551             Flushing   50.0
# 60981    Greenwich Village   50.0
# ...                    ...    ...
# 102046            Bushwick    NaN
# 102047        Williamsburg    NaN
# 102048     Upper West Side    NaN
# 102049      Hell's Kitchen    NaN
# 102050  Bedford-Stuyvesant    NaN
#
# [102599 rows x 2 columns]

# %%
#19 19. Check how many rows belong to each city.

df['neighbourhood'].value_counts()
# Out:
# neighbourhood
# Bedford-Stuyvesant        7937
# Williamsburg              7775
# Harlem                    5466
# Bushwick                  4982
# Hell's Kitchen            3965
#                           ...
# Rossville                    3
# Lighthouse Hill              3
# Fort Wadsworth               2
# Glen Oaks                    2
# Chelsea, Staten Island       1
# Name: count, Length: 224, dtype: int64

# %%
#20 20. Display only listings whose name contains the word “Cozy”.

df[df['NAME'].str.contains('cozy',case=False,na=False)]
# Out:
#              id                                            NAME      host id  \
# 5       1004098       Large Cozy 1 BR Apartment In Midtown East  45498551794
# 9       1006307              Cozy Clean Guest Room - Family Apt  75527839483
# 10      1006859              Cute & Cozy Lower East Side 1 bdrm   1280143094
# 52      1030056  Cozy 1BD on Central Park West in New York City  50562514538
# 90      1051043               Cozy Bedroom in Williamsburg 3 BR  14067827221
# ...         ...                                             ...          ...
# 102538  6061509      Cozy Bedroom in Renovated Harlem Apartment  75674201040
# 102543  6064270                              Nice and Cozy Room   6402191466
# 102547  6066479              Safe,quiet,cozy,Washington Hts Apt  92398842230
# 102553  6069793                Custom Designed Cozy Garden Apt,   7756381071
# 102564  6075868  Clean & Cozy- Private Room by Park and Subway!  33983881137
#
# ...

# %%
#21. Display all listings where price is between 100 and 200.

df[(df['price']>100)&(df['price']<200)]
# Out:
#              id                                              NAME  \
# 1       1002102                             Skylit Midtown Castle
# 14      1009068  Wonderful Guest Bedroom in Manhattan for SINGLES
# 22      1013487                    CBG CtyBGd HelpsHaiti rm#1:1-4
# 35      1020667                             Large B&B Style rooms
# 77      1043863                                    Manhattan Room
# ...         ...                                               ...
# 102500  6040521         *TERRA GARDEN* 1 Bedroom Garden Apartment
# 102534  6059299                 Upper East Side - 1 Bedroom Queen
# 102546  6065927                               LG Bright Apartment
# 102563  6075316                   Large 1Br Apt + Balcony in LES!
# 102578  6083601                Sunny & Spacious near Central Park
#
#             host id host_identity_verified host name neighbourhood group  \
# 1       52335172823               verified     Jenna           Manhattan
# ...

# %%
#22. Show all listings that are either in “Los Angeles” or “San Francisco”.

df[df['neighbourhood group'].str.contains('Francisco',case=False,na=False)]
# Out:
# Empty DataFrame
# Columns: [id, NAME, host id, host_identity_verified, host name, neighbourhood group, neighbourhood, lat, long, country, country code, instant_bookable, cancellation_policy, room type, Construction year, price, service fee, minimum nights, number of reviews, last review, reviews per month, review rate number, calculated host listings count, availability 365, house_rules, license, a]
# Index: []
#
# [0 rows x 27 columns]

# %%
#23. Retrieve listings whose number_of_reviews is greater than 50.

df[df['number of reviews']>50]
# Out:
#              id                                       NAME      host id  \
# 3       1002755                                        NaN  85098326012
# 5       1004098  Large Cozy 1 BR Apartment In Midtown East  45498551794
# 8       1005754            Large Furnished Room Near B'way  79384379533
# 9       1006307         Cozy Clean Guest Room - Family Apt  75527839483
# 10      1006859         Cute & Cozy Lower East Side 1 bdrm   1280143094
# ...         ...                                        ...          ...
# 102579  6084153            Alexander's 2BR Luxury Quarters  32736284559
# 102580  6084705        Near LGA, Citifield, US Open Tennis  97606085736
# 102584  6086914         2 block walk from the beach in NYC  70051719594
# 102587  6088571          Adorable One-Bed in Williamsburg!  20914678851
# 102588  6089124   Loft Space for Events, Meetings & Shoots  85557432222
#
#        host_identity_verified host name neighbourhood group  \
# ...

# %%
#24. Show all listings whose room_type is not “Private room”.

df[df['room type']=='Private room']
# Out:
#              id                                 NAME      host id  \
# 0       1001254   Clean & quiet apt home by the park  80014485718
# 2       1002403  THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 6       1004650                      BlissArtsSpace!  61300605564
# 7       1005202                      BlissArtsSpace!  90821839709
# 8       1005754      Large Furnished Room Near B'way  79384379533
# ...         ...                                  ...          ...
# 102589  6089676  Lrg room 1 block from Prospect Park  74549151787
# 102593  6091885  Welcoming, Clean, Cheap on St Marks  33188605074
# 102594  6092437           Spare room in Williamsburg  12312296767
# 102595  6092990        Best Location near Columbia U  77864383453
# 102596  6093542       Comfy, bright room in Brooklyn  69050334417
#
#        host_identity_verified host name neighbourhood group  \
# 0                 unconfirmed  Madaline            Brooklyn
# ...

# %%
#25. Get listings where host_name starts with the letter “A”.

df[df['host name'].str.startswith('A', na=False)]
# Out:
#              id                                             NAME      host id  \
# 6       1004650                                  BlissArtsSpace!  61300605564
# 11      1007411                 Beautiful 1br on Upper West Side  18824631834
# 18      1011277                                  Chelsea Perfect  73862528370
# 20      1012382                Huge 2 BR Upper East  Cental Park  79805143117
# 21      1012934                 Sweet and Spacious Brooklyn Loft  86554611512
# ...         ...                                              ...          ...
# 102508  6044940                 3BR Gramercy Apt in heart of NYC  59749079462
# 102521  6052120               Must Love Dogs / Bushwick Brooklyn  22301937174
# 102522  6052672              Sunny studio in the Upper East Side  16962195392
# 102573  6080839  2BR apt. in converted church with large terrace  38845651458
# 102581  6085258     Bright Bedroom in Bustling Bed Stuy Brooklyn  17339949163
#
# ...

# %%
#26. Retrieve listings whose name ends with “Suite”.

df[df['NAME'].str.endswith(' suite',na=False)]
# Out:
#               id                                               NAME  \
# 2901     2603558                   Classic Brownstone private suite
# 5233     3891522                      cute convenient village suite
# 7024     4880691                      NYC New Years Penthouse suite
# 14025    8747344                         Master Bedroom w/ en suite
# 17738   10798033                  Beautiful 2 bedroom private suite
# 18063   10977531                                Private cozy  suite
# 19573   11811504                        Carroll Gardens guest suite
# 21610   12936539                                     Private  suite
# 21802   13042581         Luxe Large Suite w/Views bathroom en suite
# 32385   18887572                                        Royal suite
# 36191   20989625             Gorgeous Cozy Brooklyn apartment suite
# 36874   21366846           Linden Estates Luxurious 2 bedroom suite
# 37708   21827464          Airy Brooklyn Limestone:  2 bedroom suite
# ...

# %%
#27. Select listings that have both price > 150 and availability_365> 200.

df[(df['price']>150)&(df['availability 365']>200)]
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# 5       1004098         Large Cozy 1 BR Apartment In Midtown East
# ...         ...                                               ...
# 102590  6090228               Wonderful artists' loft in Brooklyn
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
#28. Filter listings where neighbourhood_group equals “Manhattan” and room_type equals “Entire home/apt”.

df[(df['neighbourhood group']=='Manhatten')&(df['room type']=='Entire home/apt')]
# Out:
# Empty DataFrame
# Columns: [id, NAME, host id, host_identity_verified, host name, neighbourhood group, neighbourhood, lat, long, country, country code, instant_bookable, cancellation_policy, room type, Construction year, price, service fee, minimum nights, number of reviews, last review, reviews per month, review rate number, calculated host listings count, availability 365, house_rules, license, a]
# Index: []
#
# [0 rows x 27 columns]

# %%
df['last review']
# Out:
# 0         10/19/2021
# 1          5/21/2022
# 2                NaN
# 3           7/5/2019
# 4         11/19/2018
#              ...
# 102594           NaN
# 102595      7/6/2015
# 102596           NaN
# 102597    10/11/2015
# 102598           NaN
# Name: last review, Length: 102599, dtype: object

# %%
#29. Show all listings that were last reviewed in the year 2022. 

df['last review']=pd.to_datetime(df['last review'],errors='coerce')

df[df['last review'].dt.year==2022]
# Out:
#              id                                              NAME  \
# 1       1002102                             Skylit Midtown Castle
# 103     1058223                          Monkey Retreat Manhattan
# 189     1105721                  LARGE, COMFY 1BDR W/CHARACTER!!!
# 230     1128365                 Nice, clean, safe, convenient 3BR
# 316     1175863     Luxury 3 bed/ 2 bath apt in Harlem w/ terrace
# ...         ...                                               ...
# 69193  39216630         Cozy BX Home Away From Home ( 2 nd floor)
# 69275  39261919                    Large Room w/ Private Entrance
# 69309  39280697  Rent in beautiful Sunnyside Gardens for holidays
# 69365  39311626                   Enjoy a 1 Bedroom to share, NYC
# 69381  39320462                Cozy, Hella Sunny, and Convenient!
#
#            host id host_identity_verified  host name neighbourhood group  \
# 1      52335172823               verified      Jenna           Manhattan
# ...

# %%
#30 Display all listings where the name column contains 'Downtown'

df[df['NAME'].str.contains('Downtown',na=False)]
# Out:
#               id                                               NAME  \
# 41       1023980                                ENJOY Downtown NYC!
# 274      1152666                               ENJOY Downtown NYC!!
# 487      1270306   Very close to Downtown Awesome Private Apartment
# 516      1286323                  Comfort at Crossroads of Downtown
# 605      1335478                Great Bedroom in Downtown Manhattan
# ...          ...                                                ...
# 102043  57359685  Ultimate 50th Floor Downtown Penthouse  - 4000...
# 102129  35546044  The Residences at W New York - Downtown - Apt 27D
# 102426  20384857                     Charming 3bed/2ba Downtown/LES
# 102429  20386514    Huge Room for Nightly Stays Downtown or Monthly
# 102561   6074212  NO FEE RENTAL *Lease Takeover Modern Apt Downtown
#
#             host id host_identity_verified  host name neighbourhood group  \
# 41      63131487263            unconfirmed      Byron           Manhattan
# ...

# %%
#31 retrieve listings where reviews_per_month is greater than 2

df[df['reviews per month']>2]
# Out:
#              id                                             NAME      host id  \
# 3       1002755                                              NaN  85098326012
# 8       1005754                  Large Furnished Room Near B'way  79384379533
# 18      1011277                                  Chelsea Perfect  73862528370
# 19      1011830  Hip Historic Brownstone Apartment with Backyard  72145018858
# 31      1018457                            front room/double bed  69410526955
# ...         ...                                              ...          ...
# 102569  6078630          Elegant 1BR, Private Bath in Brownstone  37385825013
# 102575  6081944              NYC Chauncey 2 .20 min to manhattan  26326930315
# 102579  6084153                  Alexander's 2BR Luxury Quarters  32736284559
# 102580  6084705              Near LGA, Citifield, US Open Tennis  97606085736
# 102588  6089124         Loft Space for Events, Meetings & Shoots  85557432222
#
# ...

# %%
#32 select listings where host_id appers more than once

df[df['host id'].duplicated(keep=False)]
# Out:
#              id                                               NAME  \
# 9098    6026161     Upper East Side 2 bedroom- close to Hospitals-
# 9099    6026714  Close to East Side Hospitals- Modern 2 Bedroom...
# 9100    6027266  ACADIA Spacious 2 Bedroom Apt - Close to Hospi...
# 9101    6027818    *ENCHANTMENT* Upper East Side 2 bedroom- Sunny!
# 9102    6028371        *JAMES* Amazing Spacious 2 Bedroom- Bright!
# ...         ...                                                ...
# 102594  6092437                         Spare room in Williamsburg
# 102595  6092990                      Best Location near Columbia U
# 102596  6093542                     Comfy, bright room in Brooklyn
# 102597  6094094                   Big Studio-One Stop from Midtown
# 102598  6094647                               585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 9098    65193709566               verified      Juliana           Manhattan
# ...

# %%
#33 filter all listing that not located in 'Brooklyn'

df[df['neighbourhood group']!='Brooklyn']
# Out:
#              id                                              NAME  \
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# 5       1004098         Large Cozy 1 BR Apartment In Midtown East
# 8       1005754                   Large Furnished Room Near B'way
# ...         ...                                               ...
# 102592  6091333               3BR/1 Ba in TriBeCa w/ outdoor deck
# 102593  6091885               Welcoming, Clean, Cheap on St Marks
# 102595  6092990                     Best Location near Columbia U
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 1       52335172823               verified        Jenna           Manhattan
# ...

# %%
#34 Retrive listings where city column contains 'York'

df[df['NAME'].str.contains('York',na=False)]
# Out:
#               id                                              NAME  \
# 52       1030056    Cozy 1BD on Central Park West in New York City
# 170      1095227                         New York room with a view
# 397      1220599                    Authentic New York City Living
# 522      1289637                 Family & Friends in New York City
# 707      1391812                 NewYork Modern Pre-War LoftStudio
# ...          ...                                               ...
# 102405  20373259                         New York, Jackson heights
# 102409  20375468                                     New York Home
# 102411  20376572  Visit New York,The Local Brooklyn Way  SuperHost
# 102462  20404740                                New York Apartment
# 102489   6034446     Book Now & Save: Spend July in New York City!
#
#             host id host_identity_verified host name neighbourhood group  \
# 52      50562514538            unconfirmed  Madaline           Manhattan
# ...

# %%
df.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license', 'a'],
#       dtype='object')

# %%
#35 get all listings thet have price greater than the avg price
import re
df['price'] = pd.to_numeric(df['price'].str.extract(r'(\d+\.?\d*)')[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32300\2090219164.py in <cell line: 0>()
#       1 #35 get all listings thet have price greater than the avg price
#       2 import re
# ----> 3 df['price'] = pd.to_numeric(df['price'].str.extract(r'(\d+\.?\d*)')[0])
#
# ~\Documents\anaconda3\Lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# ~\Documents\anaconda3\Lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     222             # we're accessing the attribute of the class, i.e., Dataset.geo
#     223             return self._accessor
# --> 224         accessor_obj = self._accessor(obj)
# ...

# %%
import math
df[df['price']>df['price'].mean()]

# %%
#displat listings eith minimum_niights exactly equals to 7

df[df['minimum nights']==7]
# Out:
#              id                                               NAME  \
# 20      1012382                  Huge 2 BR Upper East  Cental Park
# 43      1025085                  1bdr w private bath. in lofty apt
# 45      1026190                                 BEST BET IN HARLEM
# 65      1037236  Double Room w Private Deck Clinton Hill Best Area
# 73      1041654                        Cool Room in Hell's Kitchen
# ...         ...                                                ...
# 102545  6065375                         Loft rental off of Graham!
# 102553  6069793                   Custom Designed Cozy Garden Apt,
# 102555  6070898                      Sublet entire apt in Brooklyn
# 102568  6078078                Furnished Bedroom in 2 Bedroom apt.
# 102582  6085810                Private room in the best part of BK
#
#             host id host_identity_verified     host name neighbourhood group  \
# 20      79805143117               verified        Audrey           Manhattan
# ...

# %%
#37 SELCT LISTINGS with even number of minimum nights

df[df['minimum nights']%2==0]
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# 8       1005754                   Large Furnished Room Near B'way
# ...         ...                                               ...
# 102577  6083048               Gigantic Private Brooklyn Apartment
# 102581  6085258      Bright Bedroom in Bustling Bed Stuy Brooklyn
# 102584  6086914                2 block walk from the beach in NYC
# 102586  6088019                    Patio Oasis in Upper East Side
# 102597  6094094                  Big Studio-One Stop from Midtown
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
#38 retrieve all listings whose host name length is more than 10 chars

def foo(x):
    
    if len(str(x))>10:
        return True
    else:
        return False
df[df['host name'].apply(foo)]

#     df[df['host name'].str.len()>10]
# Out:
#              id                                           NAME      host id  \
# 1073    1593954                                 Serene Room...  49750343850
# 1091    1603895            Cozy private room, williamsburg NYC  71939962014
# 1100    1608866  Sunny plant-filled apartment with 2 balconies  81188620051
# 1102    1609971                            Bright, Bedstuy Gem  14399757070
# 1113    1616046             Gorgeous Summer Duplex/Yard sublet   9729014487
# ...         ...                                            ...          ...
# 102518  6050463   Beautiful apartment in awesome Clinton Hill!  18401849962
# 102553  6069793               Custom Designed Cozy Garden Apt,   7756381071
# 102555  6070898                  Sublet entire apt in Brooklyn  83573592009
# 102569  6078630        Elegant 1BR, Private Bath in Brownstone  37385825013
# 102597  6094094               Big Studio-One Stop from Midtown  11160591270
#
# ...

# %%
#39 filter listings where price is a multiple of 50

df[df['price']%50==0]
# Out:
#               id                                             NAME  \
# 23       1014039                         CBG Helps Haiti Room#2.5
# 107      1060432                Large 2 Bedroom Great for Groups!
# 165      1092466  Charming & Cozy midtown loft any WEEK ENDS  !!!
# 183      1102407               Couldn't Be Closer To Columbia Uni
# 278      1154875                CHARMING EAST VILLAGE 2 (or 1) BR
# ...          ...                                              ...
# 102320  20326313      Spacious room in awesome Bushwick townhouse
# 102394  20367183          Sonder | Madison Ave | Modern 1BR + Gym
# 102414  20378229     Morningside Heights Cozy & Clean Modern Apt.
# 102503   6042178              Perfect for Cat, Book, Park Lovers!
# 102590   6090228              Wonderful artists' loft in Brooklyn
#
#             host id host_identity_verified  host name neighbourhood group  \
# 23      87668933180                    NaN    William            Brooklyn
# ...

# %%
#40 show names with having more than 3 words

def foo(x):
    a=str(x).split()
    if len(a)>3:
        return True
    else:
        return False

df[df['NAME'].apply(foo)]
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# 5       1004098         Large Cozy 1 BR Apartment In Midtown East
# 8       1005754                   Large Furnished Room Near B'way
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
#41rename the column neighbourhood_group to region



df=df.rename(columns={'neighbourhood group':'region'})

# %%
df.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'region', 'neighbourhood', 'lat', 'long', 'country', 'country code',
#        'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license', 'a'],
#       dtype='object')

# %%
#42 add a new column price_per_review=price/number_of_review
import numpy as np
df['ppr']=df['price']/df['number of reviews'].replace(0,np.nan)

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name     region  \
# 0       80014485718            unconfirmed     Madaline   Brooklyn
# ...

# %%
df['price'].max()
# Out:
# 1200.0

# %%
#43 create a column price_category as 'Low','Medium',or 'High' based on price ranges

def foo(x):
    if pd.isna(x):
        return 'Unknown'
    if x<=250:
        return 'low'
    elif x>250 and x<800:
        return 'Medium'
    else:
        return 'High'

df['Price_cat']=df['price'].apply(foo)

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name     region  \
# 0       80014485718            unconfirmed     Madaline   Brooklyn
# ...

# %%
#44 add a column showing the length of each listings name

df['lenName']=df['NAME'].str.len()

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name     region  \
# 0       80014485718            unconfirmed     Madaline   Brooklyn
# ...

# %%
#45 Combine city AND NEIGHBOURHOOD INTO A new location

df['location']=df['neighbourhood']+' , '+df['region']

# %%
df.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'region', 'neighbourhood', 'lat', 'long', 'country', 'country code',
#        'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license', 'a', 'ppr', 'Price_cat',
#        'lenName', 'location'],
#       dtype='object')

# %%
#46 extract the year from last_review int a new column full_location

df['year']=df['last review'].dt.year

# %%
df.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'region', 'neighbourhood', 'lat', 'long', 'country', 'country code',
#        'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license', 'a', 'ppr', 'Price_cat',
#        'lenName', 'location', 'year'],
#       dtype='object')

# %%
(df['reviews per month']>1).sum()
# Out:
# 36218

# %%
#47. Round all values in the reviews_per_month column to 2 decimal places.
import numpy as np
def foo(x):
    if pd.isna(x):
        return x
    else:
        x = x * 100
        x = int(x + 0.5)
        return x / 100
        
df['reviews per month']=df['reviews per month'].apply(foo)

# %%
df['reviews per month']
# Out:
# 0         0.21
# 1         0.38
# 2          NaN
# 3         4.64
# 4         0.10
#           ...
# 102594     NaN
# 102595    0.02
# 102596     NaN
# 102597    0.10
# 102598     NaN
# Name: reviews per month, Length: 102599, dtype: float64

# %%
#48. Replace all spaces in column names with underscores.

df['NAME1']=df['NAME'].replace(' ','_',regex=True)

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name     region  \
# 0       80014485718            unconfirmed     Madaline   Brooklyn
# ...

# %%
#49. Create a column is_available that is True if availability_365 > 0, else False.

df['is_available']=df['availability 365'].apply(lambda x : True if x>0 else False)

# %%
#50 50. Change all text in room_type to uppercase.

df['NAME1']=df['NAME1'].str.upper()

# %%
#51. Create a column price_in_inr assuming 1 USD = 83 INR.

# %%
import re
df['price']=df['price'].str.extract(r'(\d+\.?\d+)')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32300\4096157668.py in <cell line: 0>()
#       1 import re
# ----> 2 df['price']=df['price'].str.extract(r'(\d+\.?\d+)')
#
# ~\Documents\anaconda3\Lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# ~\Documents\anaconda3\Lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     222             # we're accessing the attribute of the class, i.e., Dataset.geo
#     223             return self._accessor
# --> 224         accessor_obj = self._accessor(obj)
#     225         # Replace the property with the accessor object. Inspired by:
#     226         # https://www.pydanny.com/cached-property.html
#
# ...

# %%
df['INRprice']=df['price'].astype(float)*83

# %%
df['INRprice']
# Out:
# 0         80178.0
# 1         11786.0
# 2         51460.0
# 3         30544.0
# 4         16932.0
#            ...
# 102594    70052.0
# 102595    69471.0
# 102596    82004.0
# 102597    45318.0
# 102598    85656.0
# Name: INRprice, Length: 102599, dtype: float64

# %%
#52. Reorder columns so that price comes first.
df = df[['price'] + [col for col in df.columns if col != 'price']]

# %%
df
# Out:
#          price       id                                              NAME  \
# 0        966.0  1001254                Clean & quiet apt home by the park
# 1        142.0  1002102                             Skylit Midtown Castle
# 2        620.0  1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3        368.0  1002755                                               NaN
# 4        204.0  1003689  Entire Apt: Spacious Studio/Loft by central park
# ...        ...      ...                                               ...
# 102594   844.0  6092437                        Spare room in Williamsburg
# 102595   837.0  6092990                     Best Location near Columbia U
# 102596   988.0  6093542                    Comfy, bright room in Brooklyn
# 102597   546.0  6094094                  Big Studio-One Stop from Midtown
# 102598  1032.0  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name     region  \
# ...

# %%
#53. Drop the id column from the dataset.

df.drop(columns=['id'])
# Out:
#          price                                              NAME      host id  \
# 0        966.0                Clean & quiet apt home by the park  80014485718
# 1        142.0                             Skylit Midtown Castle  52335172823
# 2        620.0               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3        368.0                                               NaN  85098326012
# 4        204.0  Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...        ...                                               ...          ...
# 102594   844.0                        Spare room in Williamsburg  12312296767
# 102595   837.0                     Best Location near Columbia U  77864383453
# 102596   988.0                    Comfy, bright room in Brooklyn  69050334417
# 102597   546.0                  Big Studio-One Stop from Midtown  11160591270
# 102598  1032.0                              585 sf Luxury Studio  68170633372
#
# ...

# %%
#54 Change the data type of price to integer.

df['price'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 102599 entries, 0 to 102598
# Series name: price
# Non-Null Count   Dtype
# --------------   -----
# 102352 non-null  float64
# dtypes: float64(1)
# memory usage: 801.7 KB

# %%
df['price']=df['price'].astype('Int64')

# %%
#55. Create a new column showing price per night: price / minimum_nights.
df['ppn']=df['price']/df['minimum nights']

# %%
df['room type']
# Out:
# 0            Private room
# 1         Entire home/apt
# 2            Private room
# 3         Entire home/apt
# 4         Entire home/apt
#                ...
# 102594       Private room
# 102595       Private room
# 102596       Private room
# 102597    Entire home/apt
# 102598    Entire home/apt
# Name: room type, Length: 102599, dtype: object

# %%
#56. Add a Boolean column indicating if the name contains the word “Luxury”.

df['lux']=df['NAME'].apply(lambda x:True if 'Luxury' in str(x) else False)

# %%
#57. Create a column for total estimated revenue = price * number_of_reviews.

df['tev']=df['price']*df['number of reviews']

# %%
#58. Replace “Entire home/apt” with “Whole Apartment” in the room_type column.

df['room type']=df['room type'].replace('Entire home/apt','Whole Apartment',regex=True)

# %%
#59 59. Change all city names to lowercase.

df['neighbourhood group']=df['neighbourhood group'].str.lower()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Documents\anaconda3\Lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\\_libs\\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\\_libs\\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'neighbourhood group'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32300\143557143.py in <cell line: 0>()
# ...

# %%
#60. Split the listing name into two columns: first word and remaining words.


#df[['1st','2nd']]=df['NAME'].str.split(n=1,expand=True)

df['first_word'] = df['NAME'].apply(lambda x: str(x).split(' ')[0])
df['remaining_words'] = df['NAME'].apply(lambda x: ''.join(str(x).split(' ')[1:]))

# %%
#61.  Find the average price for each room_type.

df.groupby('room type')['price'].mean()

# %%
#62   Find the total number of listings per neighbourhood_group.

df.groupby('neighbourhood group').size()

# %%
#63Compute the maximum and minimum price for each city.
df.groupby('neighbourhood group')['price'].agg(['min','max'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32300\382992369.py in <cell line: 0>()
#       1 #63Compute the maximum and minimum price for each city.
# ----> 2 df.groupby('neighbourhood group')['price'].agg(['min','max'])
#
# ~\Documents\anaconda3\Lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# ~\Documents\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# ...

# %%
#64 Find which host has the maximum number of listings.

df['host name'].value_counts().head(1)
# Out:
# host name
# Michael    881
# Name: count, dtype: int64

# %%
#65 Calculate the mean availability_365 for each room_type.

df.groupby('room type')['availability 365'].mean()
# Out:
# room type
# Hotel room         218.310345
# Private room       137.557126
# Shared room        172.666214
# Whole Apartment    142.760376
# Name: availability 365, dtype: float64

# %%
#66 Get the count of unique host names per city.

df.groupby('neighbourhood group')['host name'].nunique().reset_index(name='unique_host_count')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32300\429350517.py in <cell line: 0>()
#       1 #66 Get the count of unique host names per city.
#       2
# ----> 3 df.groupby('neighbourhood group')['host name'].nunique().reset_index(name='unique_host_count')
#
# ~\Documents\anaconda3\Lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# ~\Documents\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# ...

# %%
#67 For each city, find the average number of reviews.

df.groupby('neighbourhood group')['number of reviews'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32300\3384439531.py in <cell line: 0>()
#       1 #67 For each city, find the average number of reviews.
#       2
# ----> 3 df.groupby('neighbourhood group')['number of reviews'].mean()
#
# ~\Documents\anaconda3\Lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# ~\Documents\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# ...

# %%
#68.  Identify the city with the highest average price.

df.groupby('neighbourhood group')['price'].mean().sort_values(ascending=False).head(1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32300\3788876212.py in <cell line: 0>()
#       1 #68.  Identify the city with the highest average price.
#       2
# ----> 3 df.groupby('neighbourhood group')['price'].mean().sort_values(ascending=False).head(1)
#
# ~\Documents\anaconda3\Lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# ~\Documents\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# ...

# %%
#69.  Find the total revenue per host (price × number_of_reviews).

df['rev']=df['price']*df['number of reviews']

df.groupby('host name')['rev'].sum()
# Out:
# host name
# #NAME?                       85596.0
# 'Cil                        198581.0
# (Ari) HENRY LEE               7074.0
# (Email hidden by Airbnb)     16197.0
# (Mary) Haiy                 349680.0
#                               ...
# 단비                               0.0
# 빈나                            1836.0
# 소정                             836.0
# 진                                0.0
# 현선                               0.0
# Name: rev, Length: 13190, dtype: Float64

# %%
#70.  Group listings by region and show their average price.

df.groupby('neighbourhood group')['price'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32300\1824444441.py in <cell line: 0>()
#       1 #70.  Group listings by region and show their average price.
#       2
# ----> 3 df.groupby('neighbourhood group')['price'].mean()
#
# ~\Documents\anaconda3\Lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# ~\Documents\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# ...

# %%
#71.  Count how many listings exist for each minimum_nights value.

df.groupby('minimum nights').size()
# Out:
# minimum nights
# -1223.0    1
# -365.0     1
# -200.0     1
# -125.0     1
# -12.0      1
#           ..
#  1000.0    2
#  1250.0    1
#  2645.0    1
#  3455.0    1
#  5645.0    1
# Length: 153, dtype: int64

# %%
#72 Group by room_type and get the total number_of_reviews.

df.groupby('room type')['number of reviews'].sum()
# Out:
# room type
# Hotel room            9679.0
# Private room       1291669.0
# Shared room          45368.0
# Whole Apartment    1468059.0
# Name: number of reviews, dtype: float64

# %%
# 73.  Find the top 5 hosts with the highest average price.

df.groupby('host name')['price'].mean().head().reset_index()
# Out:
#                   host name   price
# 0                    #NAME?   378.0
# 1                      'Cil   569.0
# 2           (Ari) HENRY LEE  1179.0
# 3  (Email hidden by Airbnb)   343.0
# 4               (Mary) Haiy   465.0

# %%
df
# Out:
#         price       id                                              NAME  \
# 0         966  1001254                Clean & quiet apt home by the park
# 1         142  1002102                             Skylit Midtown Castle
# 2         620  1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3         368  1002755                                               NaN
# 4         204  1003689  Entire Apt: Spacious Studio/Loft by central park
# ...       ...      ...                                               ...
# 102594    844  6092437                        Spare room in Williamsburg
# 102595    837  6092990                     Best Location near Columbia U
# 102596    988  6093542                    Comfy, bright room in Brooklyn
# 102597    546  6094094                  Big Studio-One Stop from Midtown
# 102598   1032  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name     region  \
# ...

# %%
df.columns
# Out:
# Index(['price', 'id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'region', 'neighbourhood', 'lat', 'long', 'country', 'country code',
#        'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license', 'a', 'ppr', 'Price_cat',
#        'lenName', 'location', 'year', 'NAME1', 'is_available', 'INRprice',
#        'ppn', 'lux', 'tev', 'rev'],
#       dtype='object')

# %%
#74.  For each neighbourhood_group, find the listing with maximum price.

df.groupby('neighbourhood group')['price'].sum().sort_values().tail(1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32300\602808660.py in <cell line: 0>()
#       1 #74.  For each neighbourhood_group, find the listing with maximum price.
#       2
# ----> 3 df.groupby('neighbourhood group')['price'].sum().sort_values().tail(1)
#
# ~\Documents\anaconda3\Lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# ~\Documents\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# ...

# %%
#75  Group listings by both city and room_type, and compute average price.

df.groupby(['neighbourhood group','room type'])['price'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32300\85740287.py in <cell line: 0>()
#       1 #75  Group listings by both city and room_type, and compute average price.
#       2
# ----> 3 df.groupby(['neighbourhood group','room type'])['price'].mean()
#
# ~\Documents\anaconda3\Lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# ~\Documents\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# ...

# %%
#76 Get the standard deviation of price for each room_type.

df.groupby('room type')['price'].std()
# Out:
# room type
# Hotel room         310.866487
# Private room       331.332129
# Shared room        338.701626
# Whole Apartment    331.713213
# Name: price, dtype: Float64

# %%
#77.  Find how many listings were reviewed in each year.

df['last review']=pd.to_datetime(df['last review'],errors='coerce')
df['year']=df['last review'].dt.year

df.groupby('year').size()
# Out:
# year
# 2012.0       26
# 2013.0       80
# 2014.0      246
# 2015.0     1874
# 2016.0     4316
# 2017.0     6601
# 2018.0    11455
# 2019.0    42931
# 2020.0     2063
# 2021.0     6740
# 2022.0    10369
# 2024.0        1
# 2025.0        1
# 2026.0        1
# 2040.0        1
# 2058.0        1
# dtype: int64

# %%
#78.  Group listings by region and count how many have price> 100.

df[df['price']>100].groupby('region')['price'].count()
# Out:
# region
# Bronx             2608
# Brooklyn         39905
# Manhattan        41720
# Queens           12702
# Staten Island      906
# brookln              1
# manhatan             1
# Name: price, dtype: Int64

# %%
#79.  Identify which region has the most total reviews.

a=df.groupby('region')['number of reviews'].sum()
b=a.idxmax()
c=a.max()
b,c
# Out:
# ('Brooklyn', 1190962.0)

# %%
#80.  For each host_id, calculate the total availability days.

df.groupby('host id')['availability 365'].sum()
# Out:
# host id
# 123600518        0.0
# 124039648        0.0
# 124472619        0.0
# 129756565      348.0
# 130349612      205.0
#                ...
# 98758136270    117.0
# 98760968631      0.0
# 98762661810     71.0
# 98762683230     17.0
# 98763129024      0.0
# Name: availability 365, Length: 102057, dtype: float64

# %%
df
# Out:
#         price       id                                              NAME  \
# 0         966  1001254                Clean & quiet apt home by the park
# 1         142  1002102                             Skylit Midtown Castle
# 2         620  1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3         368  1002755                                               NaN
# 4         204  1003689  Entire Apt: Spacious Studio/Loft by central park
# ...       ...      ...                                               ...
# 102594    844  6092437                        Spare room in Williamsburg
# 102595    837  6092990                     Best Location near Columbia U
# 102596    988  6093542                    Comfy, bright room in Brooklyn
# 102597    546  6094094                  Big Studio-One Stop from Midtown
# 102598   1032  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name     region  \
# ...

# %%
#81.Split the dataset into two DataFrames: one with price, one with reviews, then merge them back on id.

df_price=df[['id','price']]
df_review=df[['id','number of reviews']]

pd.merge(df_price,df_review,on='id',how='inner')
# Out:
#              id  price  number of reviews
# 0       1001254    966                9.0
# 1       1002102    142               45.0
# 2       1002403    620                0.0
# 3       1002755    368              270.0
# 4       1003689    204                9.0
# ...         ...    ...                ...
# 103676  6093542    988                0.0
# 103677  6094094    546                5.0
# 103678  6094094    546                5.0
# 103679  6094647   1032                0.0
# 103680  6094647   1032                0.0
#
# [103681 rows x 3 columns]

# %%
#82.  Create a pivot table showing average price by city and room_type.

# Create a pivot table: average price by city and room_type
pivot_table = pd.pivot_table(df,
                             values='price',
                             index='region',
                             columns='room type',
                             aggfunc='mean')

pivot_table
# Out:
# room type      Hotel room  Private room  Shared room  Whole Apartment
# region
# Bronx                <NA>    634.710644    600.25641       620.232581
# Brooklyn          736.125    625.870764   634.317073       626.896406
# Manhattan          681.87    620.367881   632.522124        623.14757
# Queens             433.25    631.813996    645.30663       627.030392
# Staten Island        <NA>         603.5        715.6       642.192389
# brookln              <NA>         580.0         <NA>             <NA>
# manhatan             <NA>         460.0         <NA>             <NA>

# %%
#83 83.  Unstack a groupby result of room_type vs neighbourhood_group.

grouped=df.groupby(['region','room type']).size()

unstacked=grouped.unstack()
unstacked
# Out:
# room type      Hotel room  Private room  Shared room  Whole Apartment
# region
# Bronx                 NaN        1573.0        117.0           1022.0
# Brooklyn              8.0       20434.0        825.0          20575.0
# Manhattan           100.0       16312.0        907.0          26473.0
# Queens                8.0        7751.0        362.0           5146.0
# Staten Island         NaN         466.0         15.0            474.0
# brookln               NaN           1.0          NaN              NaN
# manhatan              NaN           1.0          NaN              NaN

# %%
#84.  Melt columns related to reviews into a long format.

melted_df = pd.melt(
    df,
    id_vars=['id', 'region'],  
    value_vars=['reviews per month', 'review rate number', 'number of reviews'],  
    var_name='review_metric',   
    value_name='value'          
)
melted_df
# Out:
#              id     region      review_metric  value
# 0       1001254   Brooklyn  reviews per month   0.21
# 1       1002102  Manhattan  reviews per month   0.38
# 2       1002403  Manhattan  reviews per month    NaN
# 3       1002755   Brooklyn  reviews per month   4.64
# 4       1003689  Manhattan  reviews per month   0.10
# ...         ...        ...                ...    ...
# 307792  6092437   Brooklyn  number of reviews   0.00
# 307793  6092990  Manhattan  number of reviews   1.00
# 307794  6093542   Brooklyn  number of reviews   0.00
# 307795  6094094     Queens  number of reviews   5.00
# 307796  6094647  Manhattan  number of reviews   0.00
#
# [307797 rows x 4 columns]

# %%
#85.  Concatenate two subsets of listings (top 10 expensive + top 10 cheapest).

exp=df.sort_values(by='price').tail(10)
che=df.sort_values(by='price').head(10)

pd.concat([exp,che])
# Out:
#         price        id                                               NAME  \
# 97775    <NA>  55002469      Studio at Upper East Side Manhattan, New York
# 97776    <NA>  55003021                               Spacious Harlem Room
# 97777    <NA>  55003573                                 Flatiron Penthouse
# 97778    <NA>  55004125                               New York Condominium
# 102045   <NA>  57360790        Private Bedroom in Rego Park / Forest Hills
# 102046   <NA>  57361342             Sunny budget friendly room in Bushwick
# 102047   <NA>  57361894            Cozy Apartment on Bedford Ave, Brooklyn
# 102048   <NA>  57362446                Your 1 bedroom home away from home!
# 102049   <NA>  57362999  MASTER Cozy Bedroom Queen size 2 blocks Timesq...
# 102050   <NA>  57363551        Sunny Brownstone Studio in BedStuy Brooklyn
# 24254      50  14396820  NEWLY Renovated Private 2 Bed Apt on 1 st Floor..
# ...

# %%
#86.  Merge two DataFrames: one with host info, one with listing info (based on host_id).

a=df[['host id','host_identity_verified','host name']]
b=df[['host id','NAME','region','neighbourhood']]

pd.merge(a,b,on='host id',how='inner')
# Out:
#             host id host_identity_verified    host name  \
# 0       80014485718            unconfirmed     Madaline
# 1       52335172823               verified        Jenna
# 2       78829239556                    NaN        Elise
# 3       85098326012            unconfirmed        Garry
# 4       92037596077               verified       Lyndon
# ...             ...                    ...          ...
# 103678  69050334417            unconfirmed        Megan
# 103679  11160591270            unconfirmed  Christopher
# 103680  11160591270            unconfirmed  Christopher
# 103681  68170633372            unconfirmed      Rebecca
# 103682  68170633372            unconfirmed      Rebecca
#
#                                                     NAME     region  \
# 0                     Clean & quiet apt home by the park   Brooklyn
# 1                                  Skylit Midtown Castle  Manhattan
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  Manhattan
# ...

# %%
df.columns
# Out:
# Index(['price', 'id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'region', 'neighbourhood', 'lat', 'long', 'country', 'country code',
#        'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license', 'a', 'ppr', 'Price_cat',
#        'lenName', 'location', 'year', 'NAME1', 'is_available', 'INRprice',
#        'ppn', 'lux', 'tev', 'rev'],
#       dtype='object')

# %%
#87.  Create a MultiIndex DataFrame grouped by city and region.

df.groupby(['region', 'neighbourhood']).agg({
    'price': 'mean',
    'number of reviews': 'sum'
})
# Out:
#                                   price  number of reviews
# region        neighbourhood
# Bronx         Allerton        636.34375             5492.0
#               Baychester          524.0             1138.0
#               Belmont        672.488889              865.0
#               Bronxdale      574.170213             1536.0
#               Castle Hill    485.181818              607.0
# ...                                 ...                ...
# Staten Island Westerleigh         477.2              100.0
#               Willowbrook         638.0               46.0
#               Woodrow        709.333333               21.0
# brookln       South Slope         580.0              167.0
# manhatan      Chelsea             460.0              260.0
#
# [226 rows x 2 columns]

# %%
#88.  Sort index after grouping by multiple columns.
